# %%
import os
os.environ["OPENAI_API_KEY"]="sk-proj-xb4t01kHNIFwlA96fMDF6KRrHXU_70fHGaVbC5uURYMh5U6GzZekXbPe1DphuTzzJUlBBtQOV5YwxeLW1ZDL5_ARfvPaJplNKnxsrjn4Jctgf1G0-iJbPGp09_pAA"

# %%
from langchain.document_loaders import PyPDFLoader
loader=PyPDFLoader(r"C:\Users\RISHYENDRA KUMAR\Downloads\FACIAL EMOTION RECOGNITION.pdf")
pdfpages=loader.load_and_split()

# %%
# !pip install pypdf tiktoken faiss-cpu
# Out:
# ...
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.6 MB 163.8 kB/s eta 0:01:29
#    ---------------------------------------- 0.0/14.6 MB 163.8 kB/s eta 0:01:29
#    ---------------------------------------- 0.0/14.6 MB 163.8 kB/s eta 0:01:29
#    ---------------------------------------- 0.0/14.6 MB 163.8 kB/s eta 0:01:29
#    ---------------------------------------- 0.1/14.6 MB 172.4 kB/s eta 0:01:25
#    ---------------------------------------- 0.1/14.6 MB 199.7 kB/s eta 0:01:13
#    ---------------------------------------- 0.1/14.6 MB 199.7 kB/s eta 0:01:13
# ...

# %%
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS
pdfstore=FAISS.from_documents(pdfpages,embedding=OpenAIEmbeddings())
FAISS.from_documents(pdfpages,embedding=OpenAIEmbeddings())
retriever=pdfstore.as_retriever()
retrieved_docs=retriever.invoke("give me the how cnn works")
print(retrieved_docs[0].page_content)
# Out:
# 20
#  Loss Function and Backpropagation:
# To train the CNN, a loss function (usually categorical cross -entropy for image
# classification) is used to measure the difference between the predicted probabilities and
# the ground truth labels. The network is optimized using backpropagation to update the
# weights and biases, minimizing the loss function, and improving the model's accuracy.
#
# Training:
# During the training process, the CNN iteratively adjusts its parameters (weights and
# biases) to learn the best features and representations for the given classification task.
# The model is trained on a labeled dataset, where the ground truth labels are used  to
# compute the loss and update the model's parameters.
#
# Inference:
# Once the CNN is trained, it can be used for inference on new, unseen images. The input
# image goes through the same convolutional and pooling layers, and the output layer
# ...

# %%
#retrieving information using a query
retriever1=pdfstore.as_retriever()
retrieved_docs1=retriever1.invoke("what is max pooling layer")
print(retrieved_docs1[0].page_content)
# Out:
# 19
#  V. Convolutional Neural Network Algorithm
#
# A Convolutional Neural Network (CNN) is a specialized type of deep learning
# algorithm designed for image classification tasks. It is inspired by the visual processing
# capabilities of the human brain and is particularly effective in extracting hierarchical
# features from images. Here's a detailed explanation of the CNN algorithm for image
# classification:
#
# Input Images:
# The CNN algorithm takes input images as its primary data. These images can be
# grayscale or color images, typically represented as 2D arrays (grayscale) or 3D arrays
# (RGB color channels).
#
# Convolutional Layer:
# The first key component of a CNN is the convolutional layer. The layer consists of a
# set of filters (also known as kernels or feature detectors) that slide over the input image
# to detect various features, such as edges, corners, and textures. Each filter p erforms a
# ...

# %%
retrieved_docs=retriever.invoke("what is accuracy?")
print(retrieved_docs[0].page_content)
# Out:
# 21
#  CHAPTER 3
#
# RESULTS AND DISCUSSIONS
#
# The results of implementing facial emotion recognition using deep learning can vary
# depending on various factors such as the dataset, model architecture, hyperparameter tuning,
# and evaluation metrics used. Here are a few possible outcomes and metrics used to assess the
# performance of facial emotion recognition models:
# • Accuracy: Accuracy measures the overall correctness of emotion predictions and is
# calculated as the ratio of correctly predicted emotions to the total number of samples
# in the dataset. Higher accuracy indicates better performance.
# • Precision and Recall: Precision measures the proportion of correctly predicted
# positive emotions, while recall measures the proportion of actual positive emotions
# correctly predicted by the model. These metrics are useful when the dataset is
# imbalanced or when certain emotions are of particular interest.
# ...

# %%
#running mulitple queries
from langchain.chat_models import ChatOpenAI
from langchain.retrievers.multi_query import MultiQueryRetriever
question="what is the conclusion of project"
llm=ChatOpenAI(temperature=1)
retriever_from_llm=MultiQueryRetriever.from_llm(
    retriever=pdfstore.as_retriever(),llm=llm
)
unique_docs=retriever_from_llm.get_relevant_documents(query=question)
print("Number of unique documents: ",len(unique_docs))
# Out:
# Number of unique documents:  6
